# %% [markdown]
# <a href="https://colab.research.google.com/github/CardosoMiguel/Open-Foam/blob/main/Resultados_OpenFoam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-15545166-d14d-4e99-8e91-db9036c67246" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15545166-d14d-4e99-8e91-db9036c67246">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving resultado_agua.csv to resultado_agua.csv
# ...

# %%
agua = pd.read_csv('resultado_agua.csv')

# %%
agua
# Out:
#       Points_0  Points_1  Points_2  ...       p_rgh  Point ID  vtkValidPointMask
# 0     0.000000    0.0002    0.0005  ...  892732.000         0                  1
# 1     0.000003    0.0002    0.0005  ...  891351.000         1                  1
# 2     0.000005    0.0002    0.0005  ...  889970.000         2                  1
# 3     0.000008    0.0002    0.0005  ...  888589.000         3                  1
# 4     0.000011    0.0002    0.0005  ...  887207.000         4                  1
# ...        ...       ...       ...  ...         ...       ...                ...
# 996   0.002739    0.0002    0.0005  ...    3307.860       996                  1
# 997   0.002742    0.0002    0.0005  ...    2480.840       997                  1
# 998   0.002744    0.0002    0.0005  ...    1653.890       998                  1
# 999   0.002747    0.0002    0.0005  ...     826.943       999                  1
# 1000  0.002750    0.0002    0.0005  ...       0.000      1000                  1
#
# ...

# %%
fig_v = plt.figure(figsize=(15,8))
fig_v.suptitle("Variação Água")

x=agua["Points_0"]
y=agua["alpha.water"]

# %%
plt.plot(x,y)
plt.show()

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-baa1a22a-c55b-47c9-9df4-6557ac95a39c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-baa1a22a-c55b-47c9-9df4-6557ac95a39c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving resultado_U.csv to resultado_U.csv
# ...

# %%
velo = pd.read_csv('resultado_U.csv')

# %%
velo
# Out:
#       Points_0  Points_1  Points_2  ...       p_rgh  Point ID  vtkValidPointMask
# 0     0.000000    0.0002    0.0005  ...  1274300.00         0                  1
# 1     0.000003    0.0002    0.0005  ...  1272920.00         1                  1
# 2     0.000005    0.0002    0.0005  ...  1271540.00         2                  1
# 3     0.000008    0.0002    0.0005  ...  1270160.00         3                  1
# 4     0.000011    0.0002    0.0005  ...  1268780.00         4                  1
# ...        ...       ...       ...  ...         ...       ...                ...
# 996   0.002739    0.0002    0.0005  ...     5617.59       996                  1
# 997   0.002742    0.0002    0.0005  ...     4213.10       997                  1
# 998   0.002744    0.0002    0.0005  ...     2808.73       998                  1
# 999   0.002747    0.0002    0.0005  ...     1404.37       999                  1
# 1000  0.002750    0.0002    0.0005  ...        0.00      1000                  1
#
# ...

# %%
fig_v = plt.figure(figsize=(15,8))
fig_v.suptitle("Velocidade")

w=agua["Points_0"]
z=agua["U_Magnitude"]

# %%
plt.plot(w,z)
plt.show()
